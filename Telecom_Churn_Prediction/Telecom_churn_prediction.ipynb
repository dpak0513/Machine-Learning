# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.metrics import confusion_matrix,f1_score,recall_score,precision_score,accuracy_score,classification_report,roc_auc_score,roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
telecom_df = pd.read_csv("Telecom_Data.csv")

# %%
telecom_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
telecom_df.shape
# Out:
# (7043, 21)

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
telecom_df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
telecom_df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
y = telecom_df['Churn']
y
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object

# %%
telecom_df.drop(columns= ['Churn','customerID'],inplace = True)

# %%
telecom_df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0                 Yes           Electronic check           29.85        29.85
# 1                  No               Mailed check           56.95       1889.5
# 2                 Yes               Mailed check           53.85       108.15
# 3                  No  Bank transfer (automatic)           42.30      1840.75
# 4                 Yes           Electronic check           70.70       151.65
# ...               ...                        ...             ...          ...
# 7038              Yes               Mailed check           84.80       1990.5
# 7039              Yes    Credit card (automatic)          103.20       7362.9
# 7040              Yes           Electronic check           29.60       346.45
# 7041              Yes               Mailed check           74.40        306.6
# 7042              Yes  Bank transfer (automatic)          105.65       6844.5
#
# [7043 rows x 19 columns]

# %%
telecom_df['TotalCharges'] = pd.to_numeric(telecom_df['TotalCharges'], errors = 'coerce')
telecom_df['SeniorCitizen'] = telecom_df['SeniorCitizen'].astype(object)

# %%
telecom_df['TotalCharges'].fillna(telecom_df['TotalCharges'].mean(),inplace = True)
# Out:
# C:\Users\rosan\AppData\Local\Temp\ipykernel_1564\2625668793.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   telecom_df['TotalCharges'].fillna(telecom_df['TotalCharges'].mean(),inplace = True)

# %%
cat_cols = [col for col in telecom_df.columns if telecom_df[col].dtype == object]
con_cols = [col for col in telecom_df.columns if telecom_df[col].dtype != object]

# %%
# train test split
X_train, X_test, Y_train, Y_test = train_test_split(telecom_df, y, test_size = 0.2, random_state= 42, stratify = y )

# %%
 # filling missing values
X_train['TotalCharges'].fillna(X_train['TotalCharges'].mean(),inplace = True)
X_test['TotalCharges'].fillna(X_train['TotalCharges'].mean(),inplace = True)
# Out:
# C:\Users\rosan\AppData\Local\Temp\ipykernel_1564\1427341630.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train['TotalCharges'].fillna(X_train['TotalCharges'].mean(),inplace = True)
# C:\Users\rosan\AppData\Local\Temp\ipykernel_1564\1427341630.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test['TotalCharges'].fillna(X_train['TotalCharges'].mean(),inplace = True)

# %%
# scaling
'''std_scaler = StandardScaler()
for col in con_cols:
    X_train[col] = std_scaler.fit_transform(np.array(X_train[col]).reshape(-1,1))
    X_test[col] = std_scaler.transform(np.array(X_test[col]).reshape(-1,1))
'''
# Out:
# 'std_scaler = StandardScaler()\nfor col in con_cols:\n    X_train[col] = std_scaler.fit_transform(np.array(X_train[col]).reshape(-1,1))\n    X_test[col] = std_scaler.transform(np.array(X_test[col]).reshape(-1,1))\n'

# %%
# encoding
oe = OrdinalEncoder(unknown_value = -1,handle_unknown = 'use_encoded_value')
for col in cat_cols:
     X_train[col] = oe.fit_transform(np.array(X_train[col]).reshape(-1,1))
     X_test[col] = oe.transform(np.array(X_test[col]).reshape(-1,1))

# %%
rf = RandomForestClassifier(random_state= 42)
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# RandomizedSearchCV

params_dict = {
              'max_depth' :[5,6,7,8,9,10],
              'min_samples_split' : [3,4,5,6,7],
              'min_samples_leaf': [3,4,5,7,6], 
              'max_leaf_nodes' : [5,6,7,8,9] 
              }

rcv = RandomizedSearchCV(rf,param_distributions = params_dict,cv = 5,n_iter = 100,verbose = 3)

rcv.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=4;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=4;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=4;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=4;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=3;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=3;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=3;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.802 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.801 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.791 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=4;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=4;, score=0.781 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=4;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=4;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=4;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=4;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=4;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=4;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=4;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=4;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=4;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=4;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=4;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=4;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=3;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=3;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=7;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=7;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=7;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=6, min_samples_split=7;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=7;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=7;, score=0.781 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=7;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=7;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=3;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=3;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=3;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=3;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=7;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=7;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=7;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=4;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=4;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=4;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=4;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=4;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=4;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=4;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=4;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.777 total time=   0.2s
# [CV 5/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.788 total time=   0.2s
# [CV 1/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.782 total time=   0.2s
# [CV 5/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=4, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=4;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=5;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=5;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.800 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.781 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=3;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=3;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=3;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=3;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=4;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=4;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=4;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=4;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=4;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=5;, score=0.794 total time=   0.2s
# [CV 2/5] END max_depth=7, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=5;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=5;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=5;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=6;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=6;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=6;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=6;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=6;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=6;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=6;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=6;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=6;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.802 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.797 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=7;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=7;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=7;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=7;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=3;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=3;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=3;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=3;, score=0.781 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=3;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=3;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=3;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=3;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=3;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=3;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=3;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=6, min_samples_split=3;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.798 total time=   0.2s
# [CV 4/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.782 total time=   0.2s
# [CV 5/5] END max_depth=7, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=6;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=4;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=4;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=4;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=4;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=6;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=6;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=6, min_samples_leaf=5, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=7;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=3;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=3;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=3;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=6;, score=0.802 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=6;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=6;, score=0.797 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=4, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=7;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=4;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=4;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=4;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=4;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=4;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=3;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=3;, score=0.781 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=3;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=3;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=3, min_samples_split=3;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=3, min_samples_split=7;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=3, min_samples_split=7;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=3, min_samples_split=7;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=3, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=3, min_samples_split=7;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=4;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=4;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=4;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=4;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=3;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=3;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=3;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=3;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=6;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=6;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=6;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=6;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.802 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.789 total time=   0.2s
# [CV 3/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.801 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=3;, score=0.791 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=5;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=5;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=8, min_samples_leaf=5, min_samples_split=5;, score=0.792 total time=   0.2s
# [CV 1/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=4;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=4;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=4;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=4;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=5;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=5;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=5;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=5;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=6;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.802 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.797 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=5;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=5;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=5;, score=0.777 total time=   0.2s
# [CV 5/5] END max_depth=8, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=5;, score=0.788 total time=   0.2s
# [CV 1/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=4;, score=0.797 total time=   0.2s
# [CV 2/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=4;, score=0.783 total time=   0.2s
# [CV 3/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=4;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=4;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=4;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=6, min_samples_leaf=7, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=4;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.797 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.781 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.796 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.788 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.777 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=6, min_samples_leaf=3, min_samples_split=7;, score=0.788 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=7;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=7;, score=0.781 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=7;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=4, min_samples_split=7;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=4;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=5;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=5;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=5;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=4, min_samples_split=3;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.802 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.801 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=9, min_samples_leaf=3, min_samples_split=3;, score=0.791 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=7;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=7;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=7;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=7;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.787 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.799 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=8, min_samples_leaf=7, min_samples_split=5;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=7;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=7;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=7;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=7;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=7, max_leaf_nodes=9, min_samples_leaf=6, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=6;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=6;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=6;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=5, min_samples_leaf=6, min_samples_split=6;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=7;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=7;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=7;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=8, max_leaf_nodes=9, min_samples_leaf=7, min_samples_split=7;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=6;, score=0.803 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=6;, score=0.788 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=6;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=6;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=9, min_samples_leaf=5, min_samples_split=6;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.797 total time=   0.1s
# [CV 4/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.781 total time=   0.1s
# [CV 5/5] END max_depth=5, max_leaf_nodes=7, min_samples_leaf=7, min_samples_split=7;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=7, min_samples_split=3;, score=0.785 total time=   0.1s
# [CV 1/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=4;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=4;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=4;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=4;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=10, max_leaf_nodes=7, min_samples_leaf=6, min_samples_split=4;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=7;, score=0.802 total time=   0.1s
# [CV 2/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=7;, score=0.789 total time=   0.1s
# [CV 3/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=7;, score=0.797 total time=   0.1s
# [CV 4/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 5/5] END max_depth=6, max_leaf_nodes=9, min_samples_leaf=4, min_samples_split=7;, score=0.792 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.797 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.798 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.782 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=7, min_samples_leaf=5, min_samples_split=5;, score=0.790 total time=   0.1s
# [CV 1/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=7;, score=0.794 total time=   0.1s
# [CV 2/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=7;, score=0.783 total time=   0.1s
# [CV 3/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=7;, score=0.787 total time=   0.1s
# [CV 4/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=7;, score=0.778 total time=   0.1s
# [CV 5/5] END max_depth=9, max_leaf_nodes=5, min_samples_leaf=3, min_samples_split=7;, score=0.785 total time=   0.1s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=100,
#                    param_distributions={'max_depth': [5, 6, 7, 8, 9, 10],
#                                         'max_leaf_nodes': [5, 6, 7, 8, 9],
#                                         'min_samples_leaf': [3, 4, 5, 7, 6],
#                                         'min_samples_split': [3, 4, 5, 6, 7]},
#                    verbose=3)

# %%
Y_pred = rcv.predict(X_test)
Y_pred
# Out:
# array(['No', 'Yes', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
Y_prob = rcv.predict_proba(X_test)[:,1]
Y_prob
# Out:
# array([0.08861775, 0.5323577 , 0.10766914, ..., 0.14288597, 0.05832835,
#        0.07091213])

# %%
rcv.best_params_
# Out:
# {'min_samples_split': 4,
#  'min_samples_leaf': 6,
#  'max_leaf_nodes': 9,
#  'max_depth': 5}

# %%
rcv.best_score_
# Out:
# np.float64(0.7930419337400572)

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.7934705464868701

# %%
cm = confusion_matrix(Y_test,Y_pred)
sns.heatmap(cm,annot= True, fmt= 'd')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.81      0.94      0.87      1035
#          Yes       0.70      0.39      0.50       374
#
#     accuracy                           0.79      1409
#    macro avg       0.76      0.66      0.68      1409
# weighted avg       0.78      0.79      0.77      1409

# %%
roc_auc_score(Y_test,Y_prob)
# Out:
# np.float64(0.8343718515074013)

# %%
importance = pd.Series(rf.feature_importances_,index=telecom_df.columns).sort_values(ascending= False)
importance.head(10)
# Out:
# TotalCharges       0.186751
# MonthlyCharges     0.179257
# tenure             0.154475
# Contract           0.079580
# PaymentMethod      0.050087
# OnlineSecurity     0.049568
# TechSupport        0.043567
# gender             0.027918
# InternetService    0.027767
# OnlineBackup       0.027053
# dtype: float64

# %%
results = X_test.copy()
results['Actual_Churn'] = Y_test.values
results['Predicted_Churn'] = Y_pred
results['Churn_Probability'] = Y_prob
results.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 437      1.0            0.0      1.0         1.0      72           1.0
# 2280     0.0            1.0      0.0         0.0       8           1.0
# 2235     0.0            0.0      1.0         1.0      41           1.0
# 4460     1.0            0.0      1.0         0.0      18           1.0
# 3761     0.0            0.0      1.0         0.0      72           1.0
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  ...  \
# 437             2.0              1.0             2.0           2.0  ...
# 2280            2.0              1.0             0.0           0.0  ...
# 2235            2.0              0.0             2.0           2.0  ...
# 4460            0.0              1.0             0.0           0.0  ...
# 3761            2.0              0.0             2.0           2.0  ...
#
#       StreamingTV  StreamingMovies  Contract  PaperlessBilling  PaymentMethod  \
# 437           2.0              2.0       2.0               1.0            1.0
# 2280          2.0              2.0       0.0               1.0            1.0
# 2235          2.0              0.0       1.0               1.0            1.0
# 4460          0.0              0.0       0.0               0.0            2.0
# 3761          2.0              2.0       2.0               1.0            1.0
#
#       MonthlyCharges  TotalCharges  Actual_Churn  Predicted_Churn  \
# 437           114.05       8468.20            No               No
# 2280          100.15        908.55            No              Yes
# 2235           78.35       3211.20            No               No
# 4460           78.20       1468.75            No               No
# 3761           82.65       5919.35            No               No
#
#      Churn_Probability
# 437           0.088618
# 2280          0.532358
# 2235          0.107669
# 4460          0.343389
# 3761          0.102429
#
# [5 rows x 22 columns]
